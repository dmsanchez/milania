# %%
for linea in open('../files/encuestarabanos.txt'):
    linea = linea.strip()

# %%
for linea in open('../files/encuestarabanos.txt'):
    linea = linea.strip()
    partes = linea.split(' - ')
    nombre = partes[0]
    voto = partes[1]
    print(nombre + " voto por " + voto)
# Out:
# Evie Pulsford voto por April Cross
# Matilda Condon voto por April Cross
# Samantha Mansell voto por Champion
# geronima trevisani voto por cherry belle
# Alexandra Shoebridge voto por Snow Belle
# Sarah Ahuia Ova voto por Snow Belle
# Emma Slattery voto por Bunny Tail
# Fabiana  Milanesi voto por Champion
# Makayla McMinn voto por Snow Belle
# Julian O'Leary voto por Sicily Giant
# Hannah Collie voto por Bunny Tail
# Toby Lundie voto por Plum Purple
# Baldo Palerma voto por Champion
# Phoebe Barwell voto por Plum Purple
# Sheng Shen voto por Champion
# Jonathan Rolph voto por Snow Belle
# Aaron Yarnold voto por Red King
# Indiana angwin voto por  Daikon
# Luke Komine voto por White Icicle
# Blake Ricardo voto por Daikon
# Mikayla Biddell voto por Daikon
# Piper Wheelwright voto por Bunny Tail
# Bailey Derrington voto por White Icicle
# Eufrosina Ferri voto por Daikon
# Madeleine Abrahams voto por Daikon
# Indiana Cowper voto por Sicily Giant
# Procopio Zito voto por Red King
# ...
